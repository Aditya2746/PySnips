# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv')
schema_df = pd.read_csv('data/survey_results_schema.csv')

# %%
pd.set_option('display.max_columns', 61)
pd.set_option('display.max_rows', 61)

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
#      CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# ...

# %%
df.rename(columns={'CompTotal' : 'Salary', 'ConvertedComp': 'Salary in USD', 'CompFreq':'Salary Frequency'}, inplace=True)

# %%
df.sort_values(by=['Country', 'Salary in USD'], ascending=[True, False], inplace=True)

# %%
df.head(500)
# Out:
#        Respondent                              MainBranch Hobbyist   Age  \
# 61540       62788          I am a developer by profession      Yes   NaN
# 63925       65381          I am a developer by profession       No   NaN
# 63993       65456          I am a developer by profession      Yes   NaN
# 38261       38672          I am a developer by profession       No   NaN
# 28270       28374          I am a developer by profession      Yes   NaN
# ...           ...                                     ...      ...   ...
# 886           888          I am a developer by profession      Yes  26.0
# 1442         1448          I am a developer by profession      Yes  35.0
# 3198         3212             I code primarily as a hobby      Yes  16.0
# 4060         4076  I am a student who is learning to code       No  23.0
# 4393         4409          I am a developer by profession      Yes   NaN
#
#                  Age1stCode Salary Frequency        Salary  Salary in USD  \
# ...

# %%
filt = df['Country'] == 'India'

# %%
df['Salary in USD'].nlargest(10)
# Out:
# 5701     2000000.0
# 53175    2000000.0
# 42657    2000000.0
# 58136    2000000.0
# 45753    2000000.0
# 121      2000000.0
# 123      2000000.0
# 191      2000000.0
# 663      2000000.0
# 697      2000000.0
# Name: Salary in USD, dtype: float64

# %%
df.nlargest(10, 'Salary in USD')
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 5701         5725                     I am a developer by profession       No
# 53175       54263                     I am a developer by profession      Yes
# 42657       43430                     I am a developer by profession      Yes
# 58136       59279                     I am a developer by profession      Yes
# 45753       46711                     I am a developer by profession      Yes
# 121           123                     I am a developer by profession      Yes
# 123           125  I am not primarily a developer, but I write co...      Yes
# 191           193                     I am a developer by profession      Yes
# 663           665                     I am a developer by profession      Yes
# 697           699  I am not primarily a developer, but I write co...      Yes
#
#         Age            Age1stCode Salary Frequency        Salary  \
# ...

# %%
df.nsmallest(10, 'Salary in USD')
# Out:
# --------------------------------------------------------------------------
# IndexError                               Traceback (most recent call last)
# <ipython-input-13-b36b0955d7e2> in <module>
# ----> 1 df.loc[['Country' == "India"]].nsmallest(10, 'Salary in USD')
#
# c:\users\admin\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     892
#     893             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 894             return self._getitem_axis(maybe_callable, axis=axis)
#     895
#     896     def _is_scalar_access(self, key: Tuple):
#
# c:\users\admin\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1101             return self._get_slice_axis(key, axis=axis)
#    1102         elif com.is_bool_indexer(key):
# -> 1103             return self._getbool_axis(key, axis=axis)
#    1104         elif is_list_like_indexer(key):
# ...
